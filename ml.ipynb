# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("flam.csv")

# %%
df
# Out:
#                Filament  Ultimate Strength(Mpa)  Price (per kg)  Density  \
# 0                   ABS                    40.0            25.0   1.0400
# 1              Flexible                    34.5            50.0   1.2100
# 2                   PLA                    65.0            25.0   1.2400
# 3                  HIPS                    32.0            28.0   1.0350
# 4                  PETG                    53.0            40.0   1.2300
# 5                 Nylon                    62.5            45.0   1.1000
# 6   Carbon Fiber Filled                    46.5            55.0   1.3000
# 7                   ASA                    55.0            39.0   1.0700
# 8         Polycarbonate                    72.0            57.5   1.2000
# 9         Polypropylene                    32.0            90.0   0.9000
# 10         Metal Filled                    25.0            85.0   3.0000
# 11          Wood Filled                    46.0            40.0   1.2000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Filament                53 non-null     object
#  1   Ultimate Strength(Mpa)  53 non-null     float64
#  2   Price (per kg)          53 non-null     float64
#  3   Density                 53 non-null     float64
#  4    Stiffness              53 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.2+ KB

# %%
fig, ax = plt.subplots(1,1, figsize=(4, 4))
df.boxplot('Price (per kg)', 'Filament', ax=ax)
plt.suptitle('Price (per kg) (US$) v Filament')
plt.title('')
plt.ylabel('Price (per kg)')
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df=pd.read_csv('flam.csv')
X = df.drop(columns=['Filament'])
y= df['Filament']
model=DecisionTreeClassifier()
model.fit(X, y)
predictions = model.predict(X)
model.fit(X,y)
df
# Out:
#                Filament  Ultimate Strength(Mpa)  Price (per kg)  Density  \
# 0                   ABS                    40.0            25.0   1.0400
# 1              Flexible                    34.5            50.0   1.2100
# 2                   PLA                    65.0            25.0   1.2400
# 3                  HIPS                    32.0            28.0   1.0350
# 4                  PETG                    53.0            40.0   1.2300
# 5                 Nylon                    62.5            45.0   1.1000
# 6   Carbon Fiber Filled                    46.5            55.0   1.3000
# 7                   ASA                    55.0            39.0   1.0700
# 8         Polycarbonate                    72.0            57.5   1.2000
# 9         Polypropylene                    32.0            90.0   0.9000
# 10         Metal Filled                    25.0            85.0   3.0000
# 11          Wood Filled                    46.0            40.0   1.2000
# ...

# %%
model=DecisionTreeClassifier()
model.fit(X,y)
predictions = model.predict([[90, 85, 90, 95]])
predictions
# Out:
# C:\Users\LENOVO\anaconda3\envs\ml\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Metal Filled'], dtype=object)

# %%
train_test_split(X, y, test_size=0.52)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.52)
model=DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
score = accuracy_score(y_test, predictions)
score
# Out:
# 0.6785714285714286
